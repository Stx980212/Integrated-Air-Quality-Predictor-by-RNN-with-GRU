# %%
import pandas as pd
import numpy as np
import sys, os
from IPython.display import display

# %% [markdown]
# ## Request Solar Data from NSRDB

# %%
# Declare all variables as strings. Spaces must be replaced with '+', i.e., change 'John Smith' to 'John+Smith'.
  # Define the lat, long of the location and the year
lat, lon, year = 34.05, -118.24, 2010
  # You must request an NSRDB api key from the link above
api_key = 'CvkzSIZGV3OxJgzOAak39Yh8AzwYnlSyJ0lKUzaa'
  # Set the attributes to extract (e.g., dhi, ghi, etc.), separated by commas.
attributes = 'ghi,dhi,dni,wind_speed,wind_direction,air_temperature,solar_zenith_angle'
  # Choose year of data
year = '2010'
  # Set leap year to true or false. True will return leap day data if present, false will not.
leap_year = 'false'
  # Set time interval in minutes, i.e., '30' is half hour intervals. Valid intervals are 30 & 60.
interval = '60'
  # Specify Coordinated Universal Time (UTC), 'true' will use UTC, 'false' will use the local time zone of the data.
  # NOTE: In order to use the NSRDB data in SAM, you must specify UTC as 'false'. SAM requires the data to be in the
  # local time zone.
utc = 'false'
  # Your full name, use '+' instead of spaces.
your_name = 'Tianxiao+Shen'
  # Your reason for using the NSRDB.
reason_for_use = 'Course+Project'
  # Your affiliation
your_affiliation = 'Columbia+University'
  # Your email address
your_email = 'ts3326@columbia.edu'
  # Please join our mailing list so we can keep you up-to-date on new developments.
mailing_list = 'false'

  # Declare url string
url = 'https://developer.nrel.gov/api/solar/nsrdb_psm3_download.csv?wkt=POINT({lon}%20{lat})&names={year}&leap_day={leap}&interval={interval}&utc={utc}&full_name={name}&email={email}&affiliation={affiliation}&mailing_list={mailing_list}&reason={reason}&api_key={api}&attributes={attr}'.format(year=year, lat=lat, lon=lon, leap=leap_year, interval=interval, utc=utc, name=your_name, email=your_email, mailing_list=mailing_list, affiliation=your_affiliation, reason=reason_for_use, api=api_key, attr=attributes)
  # Return just the first 2 lines to get metadata:
info = pd.read_csv(url, nrows=1)
  # See metadata for specified properties, e.g., timezone and elevation
timezone, elevation = info['Local Time Zone'], info['Elevation']

# %%
# Return all but first 2 lines of csv to get data:
df = pd.read_csv(url, skiprows=2)

  # Set the time index in the pandas dataframe:
df = df.set_index(pd.date_range('1/1/{yr}'.format(yr=year), freq=interval+'Min', periods=525600/int(interval)))

  # take a look
print('shape:',df.shape)
df.head()
# Out:
# shape: (8760, 12)
#                      Year  Month  Day  Hour  Minute  GHI  DHI  DNI  \
# 2010-01-01 00:00:00  2010      1    1     0      30    0    0    0
# 2010-01-01 01:00:00  2010      1    1     1      30    0    0    0
# 2010-01-01 02:00:00  2010      1    1     2      30    0    0    0
# 2010-01-01 03:00:00  2010      1    1     3      30    0    0    0
# 2010-01-01 04:00:00  2010      1    1     4      30    0    0    0
#
#                      Wind Speed  Wind Direction  Temperature  \
# 2010-01-01 00:00:00         2.4            64.8            9
# 2010-01-01 01:00:00         2.6            62.7            9
# 2010-01-01 02:00:00         2.8            60.9            8
# 2010-01-01 03:00:00         3.0            57.4            8
# 2010-01-01 04:00:00         3.5            52.4            9
#
#                      Solar Zenith Angle
# 2010-01-01 00:00:00              166.71
# 2010-01-01 01:00:00              156.73
# 2010-01-01 02:00:00              144.73
# 2010-01-01 03:00:00              132.33
# 2010-01-01 04:00:00              119.97

# %% [markdown]
# ## Request AQI Pollutant Data from USEPA AQS

# %%
from urllib.request import urlopen
import json

# %%
def request_AQI_data(year, site, param):
    email = "ts3326@columbia.edu"
    key   = "rubymallard71"
    bdate = "%i0101"%year
    edate = "%i1231"%year
    state = "06"
    county= "037"
    
    url = 'https://aqs.epa.gov/data/api/sampleData/bySite?email={email}&key={key}&param={param}&bdate={bdate}&edate={edate}&state={state}&county={county}&site={site}'.format(email=email, key=key, param=param, bdate=bdate, edate=edate, state=state, county=county, site=site)

    u = urlopen(url)
    resp = json.loads(u.read().decode('utf-8'))
    
    data = pd.DataFrame(columns = resp["Data"][0].keys())
    for i in resp["Data"]:
        temp = pd.DataFrame(i, index=[0])
        data = data.append(temp, ignore_index=True)
    data_sorted = data.drop(['state_code', 'county_code', 'site_number', 'parameter_code', 'poc', 'latitude', 'longitude', 'datum', 'parameter', 'date_gmt', 'time_gmt', 'units_of_measure_code', 'sample_duration_code', 'uncertainty', 'qualifier', 'method_type', 'method', 'method_code', 'state', 'county', 'date_of_last_change', 'cbsa_code'],axis=1)
    #data_sorted = data_sorted.drop(data_sorted[data_sorted["sample_duration"] == "24 HOUR"].index)
    data_sorted = data_sorted.sort_values(["date_local", "time_local"])
    data_sorted = data_sorted.reset_index()
    data_sorted.to_csv("%i_%i_%i.csv"%(year,param,site))
    
    return print("%i_%i_%i.csv"%(year,param,site) + " completed")

# %%
for i in [2016,2017,2018]:
    request_AQI_data(i, 5005, 42602)
# Out:
# 2016_42602_5005.csv completed
# 2017_42602_5005.csv completed
# 2018_42602_5005.csv completed

# %% [markdown]
# ## Request LA Historical Weather Data

# %%
from urllib.request import urlopen
import json

# %%
def request_Weather_data(year, month, days):
    q       = "Los+Angeles"
    date    = "%i-%s-01"% (year,month)
    enddate = "%i-%s-%i"% (year,month,days)
    tp      = 1
    format  = "json"
    key     = "a61d95712c3245f88cc172632212312"
    url = 'https://api.worldweatheronline.com/premium/v1/past-weather.ashx?q={q}&date={date}&enddate={enddate}&tp={tp}&format={format}&key={key}'.format(q=q, date=date, enddate=enddate, tp=tp, format=format, key=key)

    u = urlopen(url)
    resp = json.loads(u.read().decode('utf-8'))
    
    weather_data = pd.DataFrame()
    for i in resp['data']["weather"]:
        for j in i["hourly"]:
            temp = pd.DataFrame(j, index=[0])
            temp["date"] = i["date"]
            weather_data = weather_data.append(temp, ignore_index=True)
            
    data_sorted = weather_data.drop(columns = ['tempF', 'windspeedMiles', 'winddir16Point', 'weatherCode', 'weatherIconUrl', 'weatherDesc', 'precipInches','visibilityMiles','pressureInches', 'HeatIndexC', 'HeatIndexF','DewPointF', 'WindChillC', 'WindChillF', 'WindGustMiles', 'FeelsLikeC', 'FeelsLikeF', 'uvIndex'])
    
    data_sorted = data_sorted.sort_values(["date", "time"])
    data_sorted = data_sorted.reset_index()
    
    return data_sorted

# %%
months = ["01","02","03","04","05","06","07","08","09","10","11","12"]
days = [31,28,31,30,31,30,31,31,30,31,30,31]

data = pd.DataFrame()
for y in [2019]:
    for i in range(12):
        data = data.append(request_Weather_data(y,months[i],days[i]))

# %%
data['time']=data['time'].astype(int)
data = data.sort_values(["date", "time"])
data = data.set_index("date")

# %%
data = data.drop(columns = ["index"])

# %%
data.to_csv("%i_%s_weather.csv"%(y,months[i]))

# %%
q       = "Los+Angeles"
date    = "2016-01-01"
enddate = "2020-12-31"
tp      = 1
format  = "xml"
key     = "a61d95712c3245f88cc172632212312"
url = 'https://api.worldweatheronline.com/premium/v1/past-weather.ashx?q={q}&date={date}&enddate={enddate}&tp={tp}&format={format}&key={key}'.format(q=q, date=date, enddate=enddate, tp=tp, format=format, key=key)

u = urlopen(url)
resp = json.loads(u.read().decode('utf-8'))

# %%
resp
# Out:
# {'data': {'request': [{'type': 'City',
#     'query': 'Los Angeles, United States of America'}],
#   'weather': [{'date': '2016-01-01',
#     'astronomy': [{'sunrise': '06:59 AM',
#       'sunset': '04:54 PM',
#       'moonrise': 'No moonrise',
#       'moonset': '11:29 AM',
#       'moon_phase': 'Last Quarter',
#       'moon_illumination': '50'}],
#     'maxtempC': '18',
#     'maxtempF': '64',
#     'mintempC': '6',
#     'mintempF': '43',
#     'avgtempC': '13',
#     'avgtempF': '56',
#     'totalSnow_cm': '0.0',
#     'sunHour': '8.7',
#     'uvIndex': '4',
#     'hourly': [{'time': '0',
#       'tempC': '7',
#       'tempF': '45',
#       'windspeedMiles': '9',
#       'windspeedKmph': '14',
#       'winddirDegree': '10',
#       'winddir16Point': 'N',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '35',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '7',
#       'HeatIndexF': '45',
#       'DewPointC': '-8',
#       'DewPointF': '19',
#       'WindChillC': '4',
#       'WindChillF': '40',
#       'WindGustMiles': '19',
#       'WindGustKmph': '30',
#       'FeelsLikeC': '4',
#       'FeelsLikeF': '40',
#       'uvIndex': '1'},
#      {'time': '100',
#       'tempC': '7',
#       'tempF': '44',
#       'windspeedMiles': '9',
#       'windspeedKmph': '14',
#       'winddirDegree': '17',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '34',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '1',
#       'HeatIndexC': '7',
#       'HeatIndexF': '44',
#       'DewPointC': '-8',
#       'DewPointF': '18',
#       'WindChillC': '4',
#       'WindChillF': '39',
#       'WindGustMiles': '19',
#       'WindGustKmph': '30',
#       'FeelsLikeC': '4',
#       'FeelsLikeF': '39',
#       'uvIndex': '1'},
#      {'time': '200',
#       'tempC': '7',
#       'tempF': '44',
#       'windspeedMiles': '9',
#       'windspeedKmph': '14',
#       'winddirDegree': '25',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '34',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '1',
#       'HeatIndexC': '7',
#       'HeatIndexF': '44',
#       'DewPointC': '-8',
#       'DewPointF': '17',
#       'WindChillC': '4',
#       'WindChillF': '39',
#       'WindGustMiles': '19',
#       'WindGustKmph': '30',
#       'FeelsLikeC': '4',
#       'FeelsLikeF': '39',
#       'uvIndex': '1'},
#      {'time': '300',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '9',
#       'windspeedKmph': '14',
#       'winddirDegree': '32',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '34',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '2',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '-8',
#       'DewPointF': '17',
#       'WindChillC': '3',
#       'WindChillF': '38',
#       'WindGustMiles': '19',
#       'WindGustKmph': '30',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '38',
#       'uvIndex': '1'},
#      {'time': '400',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '9',
#       'windspeedKmph': '15',
#       'winddirDegree': '24',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '34',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '2',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '-9',
#       'DewPointF': '17',
#       'WindChillC': '3',
#       'WindChillF': '38',
#       'WindGustMiles': '19',
#       'WindGustKmph': '30',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '38',
#       'uvIndex': '1'},
#      {'time': '500',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '9',
#       'windspeedKmph': '15',
#       'winddirDegree': '15',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '34',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1021',
#       'pressureInches': '30',
#       'cloudcover': '3',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '-9',
#       'DewPointF': '16',
#       'WindChillC': '3',
#       'WindChillF': '38',
#       'WindGustMiles': '19',
#       'WindGustKmph': '31',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '38',
#       'uvIndex': '1'},
#      {'time': '600',
#       'tempC': '6',
#       'tempF': '43',
#       'windspeedMiles': '9',
#       'windspeedKmph': '15',
#       'winddirDegree': '6',
#       'winddir16Point': 'N',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '33',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1021',
#       'pressureInches': '30',
#       'cloudcover': '3',
#       'HeatIndexC': '6',
#       'HeatIndexF': '43',
#       'DewPointC': '-9',
#       'DewPointF': '16',
#       'WindChillC': '3',
#       'WindChillF': '38',
#       'WindGustMiles': '19',
#       'WindGustKmph': '31',
#       'FeelsLikeC': '3',
#       'FeelsLikeF': '38',
#       'uvIndex': '3'},
#      {'time': '700',
#       'tempC': '9',
#       'tempF': '48',
#       'windspeedMiles': '9',
#       'windspeedKmph': '14',
#       'winddirDegree': '22',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '29',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1021',
#       'pressureInches': '30',
#       'cloudcover': '4',
#       'HeatIndexC': '9',
#       'HeatIndexF': '48',
#       'DewPointC': '-9',
#       'DewPointF': '16',
#       'WindChillC': '7',
#       'WindChillF': '44',
#       'WindGustMiles': '16',
#       'WindGustKmph': '26',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '44',
#       'uvIndex': '3'},
#      {'time': '800',
#       'tempC': '12',
#       'tempF': '53',
#       'windspeedMiles': '9',
#       'windspeedKmph': '14',
#       'winddirDegree': '37',
#       'winddir16Point': 'NE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '24',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1021',
#       'pressureInches': '30',
#       'cloudcover': '6',
#       'HeatIndexC': '12',
#       'HeatIndexF': '53',
#       'DewPointC': '-9',
#       'DewPointF': '16',
#       'WindChillC': '10',
#       'WindChillF': '50',
#       'WindGustMiles': '13',
#       'WindGustKmph': '21',
#       'FeelsLikeC': '10',
#       'FeelsLikeF': '50',
#       'uvIndex': '4'},
#      {'time': '900',
#       'tempC': '14',
#       'tempF': '58',
#       'windspeedMiles': '9',
#       'windspeedKmph': '14',
#       'winddirDegree': '53',
#       'winddir16Point': 'NE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '19',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1021',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '14',
#       'HeatIndexF': '58',
#       'DewPointC': '-9',
#       'DewPointF': '16',
#       'WindChillC': '14',
#       'WindChillF': '56',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '14',
#       'FeelsLikeF': '56',
#       'uvIndex': '4'},
#      {'time': '1000',
#       'tempC': '15',
#       'tempF': '60',
#       'windspeedMiles': '7',
#       'windspeedKmph': '11',
#       'winddirDegree': '75',
#       'winddir16Point': 'ENE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '18',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1021',
#       'pressureInches': '30',
#       'cloudcover': '10',
#       'HeatIndexC': '15',
#       'HeatIndexF': '60',
#       'DewPointC': '-9',
#       'DewPointF': '16',
#       'WindChillC': '15',
#       'WindChillF': '59',
#       'WindGustMiles': '8',
#       'WindGustKmph': '13',
#       'FeelsLikeC': '15',
#       'FeelsLikeF': '59',
#       'uvIndex': '5'},
#      {'time': '1100',
#       'tempC': '17',
#       'tempF': '62',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '98',
#       'winddir16Point': 'E',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '17',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '13',
#       'HeatIndexC': '17',
#       'HeatIndexF': '62',
#       'DewPointC': '-8',
#       'DewPointF': '17',
#       'WindChillC': '17',
#       'WindChillF': '62',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '17',
#       'FeelsLikeF': '62',
#       'uvIndex': '5'},
#      {'time': '1200',
#       'tempC': '18',
#       'tempF': '64',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '120',
#       'winddir16Point': 'ESE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '16',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '16',
#       'HeatIndexC': '18',
#       'HeatIndexF': '64',
#       'DewPointC': '-8',
#       'DewPointF': '18',
#       'WindChillC': '18',
#       'WindChillF': '64',
#       'WindGustMiles': '4',
#       'WindGustKmph': '6',
#       'FeelsLikeC': '18',
#       'FeelsLikeF': '64',
#       'uvIndex': '5'},
#      {'time': '1300',
#       'tempC': '18',
#       'tempF': '64',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '144',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '19',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '13',
#       'HeatIndexC': '18',
#       'HeatIndexF': '64',
#       'DewPointC': '-6',
#       'DewPointF': '21',
#       'WindChillC': '18',
#       'WindChillF': '64',
#       'WindGustMiles': '4',
#       'WindGustKmph': '6',
#       'FeelsLikeC': '18',
#       'FeelsLikeF': '64',
#       'uvIndex': '5'},
#      {'time': '1400',
#       'tempC': '17',
#       'tempF': '63',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '167',
#       'winddir16Point': 'SSE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '22',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '11',
#       'HeatIndexC': '17',
#       'HeatIndexF': '63',
#       'DewPointC': '-5',
#       'DewPointF': '23',
#       'WindChillC': '17',
#       'WindChillF': '63',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '17',
#       'FeelsLikeF': '63',
#       'uvIndex': '5'},
#      {'time': '1500',
#       'tempC': '17',
#       'tempF': '63',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '190',
#       'winddir16Point': 'S',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '25',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '30',
#       'cloudcover': '8',
#       'HeatIndexC': '17',
#       'HeatIndexF': '63',
#       'DewPointC': '-3',
#       'DewPointF': '26',
#       'WindChillC': '17',
#       'WindChillF': '63',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '17',
#       'FeelsLikeF': '63',
#       'uvIndex': '5'},
#      {'time': '1600',
#       'tempC': '15',
#       'tempF': '59',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '128',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '26',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '15',
#       'HeatIndexF': '59',
#       'DewPointC': '-4',
#       'DewPointF': '24',
#       'WindChillC': '15',
#       'WindChillF': '59',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '15',
#       'FeelsLikeF': '59',
#       'uvIndex': '5'},
#      {'time': '1700',
#       'tempC': '13',
#       'tempF': '55',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '66',
#       'winddir16Point': 'ENE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '28',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '6',
#       'HeatIndexC': '13',
#       'HeatIndexF': '55',
#       'DewPointC': '-5',
#       'DewPointF': '23',
#       'WindChillC': '12',
#       'WindChillF': '54',
#       'WindGustMiles': '9',
#       'WindGustKmph': '14',
#       'FeelsLikeC': '12',
#       'FeelsLikeF': '54',
#       'uvIndex': '4'},
#      {'time': '1800',
#       'tempC': '11',
#       'tempF': '52',
#       'windspeedMiles': '5',
#       'windspeedKmph': '9',
#       'winddirDegree': '4',
#       'winddir16Point': 'N',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '30',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '6',
#       'HeatIndexC': '11',
#       'HeatIndexF': '52',
#       'DewPointC': '-6',
#       'DewPointF': '21',
#       'WindChillC': '10',
#       'WindChillF': '50',
#       'WindGustMiles': '11',
#       'WindGustKmph': '18',
#       'FeelsLikeC': '10',
#       'FeelsLikeF': '50',
#       'uvIndex': '1'},
#      {'time': '1900',
#       'tempC': '10',
#       'tempF': '51',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '9',
#       'winddir16Point': 'N',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '28',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '12',
#       'HeatIndexC': '10',
#       'HeatIndexF': '51',
#       'DewPointC': '-7',
#       'DewPointF': '19',
#       'WindChillC': '9',
#       'WindChillF': '48',
#       'WindGustMiles': '13',
#       'WindGustKmph': '21',
#       'FeelsLikeC': '9',
#       'FeelsLikeF': '48',
#       'uvIndex': '1'},
#      {'time': '2000',
#       'tempC': '10',
#       'tempF': '49',
#       'windspeedMiles': '7',
#       'windspeedKmph': '11',
#       'winddirDegree': '14',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '27',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '17',
#       'HeatIndexC': '10',
#       'HeatIndexF': '49',
#       'DewPointC': '-8',
#       'DewPointF': '17',
#       'WindChillC': '8',
#       'WindChillF': '46',
#       'WindGustMiles': '15',
#       'WindGustKmph': '24',
#       'FeelsLikeC': '8',
#       'FeelsLikeF': '46',
#       'uvIndex': '1'},
#      {'time': '2100',
#       'tempC': '9',
#       'tempF': '48',
#       'windspeedMiles': '8',
#       'windspeedKmph': '13',
#       'winddirDegree': '19',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '26',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '23',
#       'HeatIndexC': '9',
#       'HeatIndexF': '48',
#       'DewPointC': '-10',
#       'DewPointF': '15',
#       'WindChillC': '7',
#       'WindChillF': '44',
#       'WindGustMiles': '16',
#       'WindGustKmph': '26',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '44',
#       'uvIndex': '1'},
#      {'time': '2200',
#       'tempC': '9',
#       'tempF': '48',
#       'windspeedMiles': '7',
#       'windspeedKmph': '12',
#       'winddirDegree': '15',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '26',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '32',
#       'HeatIndexC': '9',
#       'HeatIndexF': '48',
#       'DewPointC': '-10',
#       'DewPointF': '15',
#       'WindChillC': '7',
#       'WindChillF': '45',
#       'WindGustMiles': '15',
#       'WindGustKmph': '24',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '45',
#       'uvIndex': '1'},
#      {'time': '2300',
#       'tempC': '9',
#       'tempF': '48',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '11',
#       'winddir16Point': 'N',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '26',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '41',
#       'HeatIndexC': '9',
#       'HeatIndexF': '48',
#       'DewPointC': '-10',
#       'DewPointF': '15',
#       'WindChillC': '7',
#       'WindChillF': '45',
#       'WindGustMiles': '14',
#       'WindGustKmph': '22',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '45',
#       'uvIndex': '1'}]},
#    {'date': '2016-01-02',
#     'astronomy': [{'sunrise': '06:59 AM',
#       'sunset': '04:55 PM',
#       'moonrise': '12:06 AM',
#       'moonset': '12:01 PM',
#       'moon_phase': 'Last Quarter',
#       'moon_illumination': '43'}],
#     'maxtempC': '18',
#     'maxtempF': '65',
#     'mintempC': '7',
#     'mintempF': '45',
#     'avgtempC': '13',
#     'avgtempF': '56',
#     'totalSnow_cm': '0.0',
#     'sunHour': '8.7',
#     'uvIndex': '4',
#     'hourly': [{'time': '0',
#       'tempC': '9',
#       'tempF': '48',
#       'windspeedMiles': '6',
#       'windspeedKmph': '9',
#       'winddirDegree': '7',
#       'winddir16Point': 'N',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '26',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '49',
#       'HeatIndexC': '9',
#       'HeatIndexF': '48',
#       'DewPointC': '-10',
#       'DewPointF': '15',
#       'WindChillC': '7',
#       'WindChillF': '45',
#       'WindGustMiles': '12',
#       'WindGustKmph': '20',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '45',
#       'uvIndex': '1'},
#      {'time': '100',
#       'tempC': '9',
#       'tempF': '47',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '19',
#       'winddir16Point': 'NNE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '26',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '49',
#       'HeatIndexC': '9',
#       'HeatIndexF': '47',
#       'DewPointC': '-10',
#       'DewPointF': '15',
#       'WindChillC': '7',
#       'WindChillF': '45',
#       'WindGustMiles': '14',
#       'WindGustKmph': '22',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '45',
#       'uvIndex': '1'},
#      {'time': '200',
#       'tempC': '8',
#       'tempF': '47',
#       'windspeedMiles': '7',
#       'windspeedKmph': '12',
#       'winddirDegree': '31',
#       'winddir16Point': 'NNE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '26',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '49',
#       'HeatIndexC': '8',
#       'HeatIndexF': '47',
#       'DewPointC': '-10',
#       'DewPointF': '14',
#       'WindChillC': '7',
#       'WindChillF': '45',
#       'WindGustMiles': '15',
#       'WindGustKmph': '24',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '45',
#       'uvIndex': '1'},
#      {'time': '300',
#       'tempC': '8',
#       'tempF': '47',
#       'windspeedMiles': '8',
#       'windspeedKmph': '13',
#       'winddirDegree': '43',
#       'winddir16Point': 'NE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '26',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '48',
#       'HeatIndexC': '8',
#       'HeatIndexF': '47',
#       'DewPointC': '-10',
#       'DewPointF': '14',
#       'WindChillC': '7',
#       'WindChillF': '44',
#       'WindGustMiles': '16',
#       'WindGustKmph': '26',
#       'FeelsLikeC': '7',
#       'FeelsLikeF': '44',
#       'uvIndex': '1'},
#      {'time': '400',
#       'tempC': '8',
#       'tempF': '46',
#       'windspeedMiles': '7',
#       'windspeedKmph': '12',
#       'winddirDegree': '30',
#       'winddir16Point': 'NNE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0004_black_low_cloud.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '27',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '37',
#       'HeatIndexC': '8',
#       'HeatIndexF': '46',
#       'DewPointC': '-10',
#       'DewPointF': '14',
#       'WindChillC': '6',
#       'WindChillF': '43',
#       'WindGustMiles': '15',
#       'WindGustKmph': '24',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '43',
#       'uvIndex': '1'},
#      {'time': '500',
#       'tempC': '7',
#       'tempF': '45',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '18',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '28',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '26',
#       'HeatIndexC': '7',
#       'HeatIndexF': '45',
#       'DewPointC': '-10',
#       'DewPointF': '14',
#       'WindChillC': '6',
#       'WindChillF': '42',
#       'WindGustMiles': '14',
#       'WindGustKmph': '22',
#       'FeelsLikeC': '6',
#       'FeelsLikeF': '42',
#       'uvIndex': '1'},
#      {'time': '600',
#       'tempC': '7',
#       'tempF': '45',
#       'windspeedMiles': '6',
#       'windspeedKmph': '9',
#       'winddirDegree': '5',
#       'winddir16Point': 'N',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '29',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '16',
#       'HeatIndexC': '7',
#       'HeatIndexF': '45',
#       'DewPointC': '-10',
#       'DewPointF': '15',
#       'WindChillC': '5',
#       'WindChillF': '41',
#       'WindGustMiles': '12',
#       'WindGustKmph': '20',
#       'FeelsLikeC': '5',
#       'FeelsLikeF': '41',
#       'uvIndex': '3'},
#      {'time': '700',
#       'tempC': '10',
#       'tempF': '49',
#       'windspeedMiles': '6',
#       'windspeedKmph': '9',
#       'winddirDegree': '20',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '25',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '19',
#       'HeatIndexC': '10',
#       'HeatIndexF': '49',
#       'DewPointC': '-10',
#       'DewPointF': '15',
#       'WindChillC': '9',
#       'WindChillF': '47',
#       'WindGustMiles': '10',
#       'WindGustKmph': '17',
#       'FeelsLikeC': '9',
#       'FeelsLikeF': '47',
#       'uvIndex': '3'},
#      {'time': '800',
#       'tempC': '12',
#       'tempF': '54',
#       'windspeedMiles': '6',
#       'windspeedKmph': '9',
#       'winddirDegree': '35',
#       'winddir16Point': 'NE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '21',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '23',
#       'HeatIndexC': '12',
#       'HeatIndexF': '54',
#       'DewPointC': '-10',
#       'DewPointF': '15',
#       'WindChillC': '12',
#       'WindChillF': '53',
#       'WindGustMiles': '8',
#       'WindGustKmph': '13',
#       'FeelsLikeC': '12',
#       'FeelsLikeF': '53',
#       'uvIndex': '4'},
#      {'time': '900',
#       'tempC': '15',
#       'tempF': '59',
#       'windspeedMiles': '6',
#       'windspeedKmph': '9',
#       'winddirDegree': '50',
#       'winddir16Point': 'NE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '17',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1020',
#       'pressureInches': '30',
#       'cloudcover': '27',
#       'HeatIndexC': '15',
#       'HeatIndexF': '59',
#       'DewPointC': '-10',
#       'DewPointF': '15',
#       'WindChillC': '15',
#       'WindChillF': '59',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '15',
#       'FeelsLikeF': '59',
#       'uvIndex': '5'},
#      {'time': '1000',
#       'tempC': '16',
#       'tempF': '61',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '83',
#       'winddir16Point': 'E',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '17',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '30',
#       'cloudcover': '33',
#       'HeatIndexC': '16',
#       'HeatIndexF': '61',
#       'DewPointC': '-9',
#       'DewPointF': '16',
#       'WindChillC': '16',
#       'WindChillF': '61',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '16',
#       'FeelsLikeF': '61',
#       'uvIndex': '5'},
#      {'time': '1100',
#       'tempC': '17',
#       'tempF': '63',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '117',
#       'winddir16Point': 'ESE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '17',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '30',
#       'cloudcover': '39',
#       'HeatIndexC': '17',
#       'HeatIndexF': '63',
#       'DewPointC': '-8',
#       'DewPointF': '17',
#       'WindChillC': '17',
#       'WindChillF': '63',
#       'WindGustMiles': '7',
#       'WindGustKmph': '12',
#       'FeelsLikeC': '17',
#       'FeelsLikeF': '63',
#       'uvIndex': '5'},
#      {'time': '1200',
#       'tempC': '18',
#       'tempF': '65',
#       'windspeedMiles': '7',
#       'windspeedKmph': '11',
#       'winddirDegree': '151',
#       'winddir16Point': 'SSE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '17',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '30',
#       'cloudcover': '45',
#       'HeatIndexC': '18',
#       'HeatIndexF': '65',
#       'DewPointC': '-8',
#       'DewPointF': '19',
#       'WindChillC': '18',
#       'WindChillF': '65',
#       'WindGustMiles': '8',
#       'WindGustKmph': '12',
#       'FeelsLikeC': '18',
#       'FeelsLikeF': '65',
#       'uvIndex': '5'},
#      {'time': '1300',
#       'tempC': '17',
#       'tempF': '63',
#       'windspeedMiles': '6',
#       'windspeedKmph': '9',
#       'winddirDegree': '171',
#       'winddir16Point': 'S',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '22',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '30',
#       'cloudcover': '44',
#       'HeatIndexC': '17',
#       'HeatIndexF': '63',
#       'DewPointC': '-5',
#       'DewPointF': '23',
#       'WindChillC': '17',
#       'WindChillF': '63',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '17',
#       'FeelsLikeF': '63',
#       'uvIndex': '5'},
#      {'time': '1400',
#       'tempC': '17',
#       'tempF': '62',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '191',
#       'winddir16Point': 'S',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '27',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '30',
#       'cloudcover': '44',
#       'HeatIndexC': '17',
#       'HeatIndexF': '62',
#       'DewPointC': '-3',
#       'DewPointF': '27',
#       'WindChillC': '17',
#       'WindChillF': '62',
#       'WindGustMiles': '6',
#       'WindGustKmph': '10',
#       'FeelsLikeC': '17',
#       'FeelsLikeF': '62',
#       'uvIndex': '5'},
#      {'time': '1500',
#       'tempC': '16',
#       'tempF': '61',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '211',
#       'winddir16Point': 'SSW',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '33',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '30',
#       'cloudcover': '44',
#       'HeatIndexC': '16',
#       'HeatIndexF': '61',
#       'DewPointC': '-0',
#       'DewPointF': '31',
#       'WindChillC': '16',
#       'WindChillF': '61',
#       'WindGustMiles': '6',
#       'WindGustKmph': '9',
#       'FeelsLikeC': '16',
#       'FeelsLikeF': '61',
#       'uvIndex': '5'},
#      {'time': '1600',
#       'tempC': '14',
#       'tempF': '58',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '166',
#       'winddir16Point': 'SSE',
#       'weatherCode': '116',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0002_sunny_intervals.png'}],
#       'weatherDesc': [{'value': 'Partly cloudy'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '41',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '30',
#       'cloudcover': '31',
#       'HeatIndexC': '14',
#       'HeatIndexF': '58',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '14',
#       'WindChillF': '58',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '14',
#       'FeelsLikeF': '58',
#       'uvIndex': '4'},
#      {'time': '1700',
#       'tempC': '13',
#       'tempF': '55',
#       'windspeedMiles': '2',
#       'windspeedKmph': '3',
#       'winddirDegree': '120',
#       'winddir16Point': 'ESE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '50',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '30',
#       'cloudcover': '18',
#       'HeatIndexC': '13',
#       'HeatIndexF': '55',
#       'DewPointC': '2',
#       'DewPointF': '36',
#       'WindChillC': '13',
#       'WindChillF': '55',
#       'WindGustMiles': '3',
#       'WindGustKmph': '5',
#       'FeelsLikeC': '13',
#       'FeelsLikeF': '55',
#       'uvIndex': '4'},
#      {'time': '1800',
#       'tempC': '11',
#       'tempF': '52',
#       'windspeedMiles': '1',
#       'windspeedKmph': '1',
#       'winddirDegree': '75',
#       'winddir16Point': 'ENE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '59',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '30',
#       'cloudcover': '6',
#       'HeatIndexC': '11',
#       'HeatIndexF': '52',
#       'DewPointC': '3',
#       'DewPointF': '38',
#       'WindChillC': '11',
#       'WindChillF': '52',
#       'WindGustMiles': '2',
#       'WindGustKmph': '3',
#       'FeelsLikeC': '11',
#       'FeelsLikeF': '52',
#       'uvIndex': '1'},
#      {'time': '1900',
#       'tempC': '10',
#       'tempF': '51',
#       'windspeedMiles': '1',
#       'windspeedKmph': '2',
#       'winddirDegree': '61',
#       'winddir16Point': 'ENE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '58',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '10',
#       'HeatIndexF': '51',
#       'DewPointC': '2',
#       'DewPointF': '36',
#       'WindChillC': '10',
#       'WindChillF': '51',
#       'WindGustMiles': '3',
#       'WindGustKmph': '5',
#       'FeelsLikeC': '10',
#       'FeelsLikeF': '51',
#       'uvIndex': '1'},
#      {'time': '2000',
#       'tempC': '10',
#       'tempF': '50',
#       'windspeedMiles': '2',
#       'windspeedKmph': '3',
#       'winddirDegree': '47',
#       'winddir16Point': 'NE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '57',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '10',
#       'HeatIndexF': '50',
#       'DewPointC': '2',
#       'DewPointF': '35',
#       'WindChillC': '10',
#       'WindChillF': '50',
#       'WindGustMiles': '4',
#       'WindGustKmph': '6',
#       'FeelsLikeC': '10',
#       'FeelsLikeF': '50',
#       'uvIndex': '1'},
#      {'time': '2100',
#       'tempC': '9',
#       'tempF': '49',
#       'windspeedMiles': '2',
#       'windspeedKmph': '4',
#       'winddirDegree': '33',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '56',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1019',
#       'pressureInches': '30',
#       'cloudcover': '8',
#       'HeatIndexC': '9',
#       'HeatIndexF': '49',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '9',
#       'WindChillF': '49',
#       'WindGustMiles': '5',
#       'WindGustKmph': '8',
#       'FeelsLikeC': '9',
#       'FeelsLikeF': '49',
#       'uvIndex': '1'},
#      {'time': '2200',
#       'tempC': '9',
#       'tempF': '49',
#       'windspeedMiles': '2',
#       'windspeedKmph': '3',
#       'winddirDegree': '27',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '56',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '30',
#       'cloudcover': '8',
#       'HeatIndexC': '9',
#       'HeatIndexF': '49',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '9',
#       'WindChillF': '49',
#       'WindGustMiles': '5',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '9',
#       'FeelsLikeF': '49',
#       'uvIndex': '1'},
#      {'time': '2300',
#       'tempC': '9',
#       'tempF': '48',
#       'windspeedMiles': '2',
#       'windspeedKmph': '3',
#       'winddirDegree': '22',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '57',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '9',
#       'HeatIndexF': '48',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '9',
#       'WindChillF': '49',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '9',
#       'FeelsLikeF': '49',
#       'uvIndex': '1'}]},
#    {'date': '2016-01-03',
#     'astronomy': [{'sunrise': '06:59 AM',
#       'sunset': '04:56 PM',
#       'moonrise': '12:59 AM',
#       'moonset': '12:34 PM',
#       'moon_phase': 'Last Quarter',
#       'moon_illumination': '36'}],
#     'maxtempC': '16',
#     'maxtempF': '60',
#     'mintempC': '7',
#     'mintempF': '44',
#     'avgtempC': '13',
#     'avgtempF': '55',
#     'totalSnow_cm': '0.0',
#     'sunHour': '7.0',
#     'uvIndex': '4',
#     'hourly': [{'time': '0',
#       'tempC': '9',
#       'tempF': '48',
#       'windspeedMiles': '2',
#       'windspeedKmph': '3',
#       'winddirDegree': '17',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '57',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '9',
#       'HeatIndexF': '48',
#       'DewPointC': '1',
#       'DewPointF': '34',
#       'WindChillC': '9',
#       'WindChillF': '49',
#       'WindGustMiles': '4',
#       'WindGustKmph': '7',
#       'FeelsLikeC': '9',
#       'FeelsLikeF': '49',
#       'uvIndex': '1'},
#      {'time': '100',
#       'tempC': '9',
#       'tempF': '48',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '30',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '56',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1018',
#       'pressureInches': '30',
#       'cloudcover': '6',
#       'HeatIndexC': '9',
#       'HeatIndexF': '48',
#       'DewPointC': '1',
#       'DewPointF': '33',
#       'WindChillC': '9',
#       'WindChillF': '48',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '9',
#       'FeelsLikeF': '48',
#       'uvIndex': '1'},
#      {'time': '200',
#       'tempC': '9',
#       'tempF': '48',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '43',
#       'winddir16Point': 'NE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '55',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1017',
#       'pressureInches': '30',
#       'cloudcover': '5',
#       'HeatIndexC': '9',
#       'HeatIndexF': '48',
#       'DewPointC': '0',
#       'DewPointF': '32',
#       'WindChillC': '9',
#       'WindChillF': '48',
#       'WindGustMiles': '9',
#       'WindGustKmph': '14',
#       'FeelsLikeC': '9',
#       'FeelsLikeF': '48',
#       'uvIndex': '1'},
#      {'time': '300',
#       'tempC': '9',
#       'tempF': '47',
#       'windspeedMiles': '5',
#       'windspeedKmph': '9',
#       'winddirDegree': '56',
#       'winddir16Point': 'ENE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '53',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1017',
#       'pressureInches': '30',
#       'cloudcover': '5',
#       'HeatIndexC': '9',
#       'HeatIndexF': '47',
#       'DewPointC': '-0',
#       'DewPointF': '31',
#       'WindChillC': '9',
#       'WindChillF': '48',
#       'WindGustMiles': '11',
#       'WindGustKmph': '18',
#       'FeelsLikeC': '9',
#       'FeelsLikeF': '48',
#       'uvIndex': '1'},
#      {'time': '400',
#       'tempC': '8',
#       'tempF': '46',
#       'windspeedMiles': '4',
#       'windspeedKmph': '7',
#       'winddirDegree': '55',
#       'winddir16Point': 'NE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '57',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1017',
#       'pressureInches': '30',
#       'cloudcover': '29',
#       'HeatIndexC': '8',
#       'HeatIndexF': '46',
#       'DewPointC': '-0',
#       'DewPointF': '32',
#       'WindChillC': '8',
# ...
#       'DewPointF': '25',
#       'WindChillC': '8',
#       'WindChillF': '47',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '8',
#       'FeelsLikeF': '47',
#       'uvIndex': '1'},
#      {'time': '400',
#       'tempC': '9',
#       'tempF': '49',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '26',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '40',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '30',
#       'cloudcover': '15',
#       'HeatIndexC': '9',
#       'HeatIndexF': '49',
#       'DewPointC': '-4',
#       'DewPointF': '26',
#       'WindChillC': '8',
#       'WindChillF': '47',
#       'WindGustMiles': '11',
#       'WindGustKmph': '18',
#       'FeelsLikeC': '8',
#       'FeelsLikeF': '47',
#       'uvIndex': '1'},
#      {'time': '500',
#       'tempC': '10',
#       'tempF': '49',
#       'windspeedMiles': '6',
#       'windspeedKmph': '9',
#       'winddirDegree': '15',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '40',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '10',
#       'HeatIndexF': '49',
#       'DewPointC': '-3',
#       'DewPointF': '26',
#       'WindChillC': '8',
#       'WindChillF': '47',
#       'WindGustMiles': '12',
#       'WindGustKmph': '19',
#       'FeelsLikeC': '8',
#       'FeelsLikeF': '47',
#       'uvIndex': '1'},
#      {'time': '600',
#       'tempC': '10',
#       'tempF': '50',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '3',
#       'winddir16Point': 'N',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '40',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '10',
#       'HeatIndexF': '50',
#       'DewPointC': '-3',
#       'DewPointF': '27',
#       'WindChillC': '8',
#       'WindChillF': '47',
#       'WindGustMiles': '13',
#       'WindGustKmph': '21',
#       'FeelsLikeC': '8',
#       'FeelsLikeF': '47',
#       'uvIndex': '3'},
#      {'time': '700',
#       'tempC': '13',
#       'tempF': '55',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '16',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '36',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '13',
#       'HeatIndexF': '55',
#       'DewPointC': '-2',
#       'DewPointF': '28',
#       'WindChillC': '12',
#       'WindChillF': '53',
#       'WindGustMiles': '10',
#       'WindGustKmph': '16',
#       'FeelsLikeC': '12',
#       'FeelsLikeF': '53',
#       'uvIndex': '4'},
#      {'time': '800',
#       'tempC': '15',
#       'tempF': '60',
#       'windspeedMiles': '4',
#       'windspeedKmph': '6',
#       'winddirDegree': '30',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '31',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '15',
#       'HeatIndexF': '60',
#       'DewPointC': '-2',
#       'DewPointF': '29',
#       'WindChillC': '15',
#       'WindChillF': '59',
#       'WindGustMiles': '7',
#       'WindGustKmph': '11',
#       'FeelsLikeC': '15',
#       'FeelsLikeF': '59',
#       'uvIndex': '5'},
#      {'time': '900',
#       'tempC': '18',
#       'tempF': '65',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '43',
#       'winddir16Point': 'NE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '27',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1028',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '18',
#       'HeatIndexF': '65',
#       'DewPointC': '-1',
#       'DewPointF': '30',
#       'WindChillC': '18',
#       'WindChillF': '65',
#       'WindGustMiles': '3',
#       'WindGustKmph': '5',
#       'FeelsLikeC': '18',
#       'FeelsLikeF': '65',
#       'uvIndex': '5'},
#      {'time': '1000',
#       'tempC': '19',
#       'tempF': '67',
#       'windspeedMiles': '3',
#       'windspeedKmph': '4',
#       'winddirDegree': '138',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '26',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1027',
#       'pressureInches': '30',
#       'cloudcover': '3',
#       'HeatIndexC': '20',
#       'HeatIndexF': '67',
#       'DewPointC': '-1',
#       'DewPointF': '30',
#       'WindChillC': '19',
#       'WindChillF': '67',
#       'WindGustMiles': '3',
#       'WindGustKmph': '5',
#       'FeelsLikeC': '19',
#       'FeelsLikeF': '67',
#       'uvIndex': '5'},
#      {'time': '1100',
#       'tempC': '20',
#       'tempF': '68',
#       'windspeedMiles': '2',
#       'windspeedKmph': '3',
#       'winddirDegree': '232',
#       'winddir16Point': 'SW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '24',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1026',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '21',
#       'HeatIndexF': '70',
#       'DewPointC': '-1',
#       'DewPointF': '31',
#       'WindChillC': '20',
#       'WindChillF': '68',
#       'WindGustMiles': '2',
#       'WindGustKmph': '4',
#       'FeelsLikeC': '20',
#       'FeelsLikeF': '68',
#       'uvIndex': '6'},
#      {'time': '1200',
#       'tempC': '21',
#       'tempF': '70',
#       'windspeedMiles': '2',
#       'windspeedKmph': '3',
#       'winddirDegree': '327',
#       'winddir16Point': 'NNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '23',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1026',
#       'pressureInches': '30',
#       'cloudcover': '10',
#       'HeatIndexC': '22',
#       'HeatIndexF': '72',
#       'DewPointC': '-1',
#       'DewPointF': '31',
#       'WindChillC': '21',
#       'WindChillF': '70',
#       'WindGustMiles': '2',
#       'WindGustKmph': '3',
#       'FeelsLikeC': '21',
#       'FeelsLikeF': '70',
#       'uvIndex': '6'},
#      {'time': '1300',
#       'tempC': '21',
#       'tempF': '70',
#       'windspeedMiles': '2',
#       'windspeedKmph': '4',
#       'winddirDegree': '310',
#       'winddir16Point': 'NW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '24',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '30',
#       'cloudcover': '7',
#       'HeatIndexC': '22',
#       'HeatIndexF': '72',
#       'DewPointC': '-0',
#       'DewPointF': '31',
#       'WindChillC': '21',
#       'WindChillF': '70',
#       'WindGustMiles': '3',
#       'WindGustKmph': '4',
#       'FeelsLikeC': '21',
#       'FeelsLikeF': '70',
#       'uvIndex': '6'},
#      {'time': '1400',
#       'tempC': '21',
#       'tempF': '70',
#       'windspeedMiles': '3',
#       'windspeedKmph': '4',
#       'winddirDegree': '292',
#       'winddir16Point': 'WNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '24',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '30',
#       'cloudcover': '5',
#       'HeatIndexC': '22',
#       'HeatIndexF': '72',
#       'DewPointC': '-0',
#       'DewPointF': '32',
#       'WindChillC': '21',
#       'WindChillF': '70',
#       'WindGustMiles': '3',
#       'WindGustKmph': '5',
#       'FeelsLikeC': '21',
#       'FeelsLikeF': '70',
#       'uvIndex': '6'},
#      {'time': '1500',
#       'tempC': '22',
#       'tempF': '71',
#       'windspeedMiles': '3',
#       'windspeedKmph': '5',
#       'winddirDegree': '274',
#       'winddir16Point': 'W',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '24',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '30',
#       'cloudcover': '3',
#       'HeatIndexC': '22',
#       'HeatIndexF': '72',
#       'DewPointC': '0',
#       'DewPointF': '32',
#       'WindChillC': '22',
#       'WindChillF': '71',
#       'WindGustMiles': '4',
#       'WindGustKmph': '6',
#       'FeelsLikeC': '22',
#       'FeelsLikeF': '71',
#       'uvIndex': '6'},
#      {'time': '1600',
#       'tempC': '19',
#       'tempF': '66',
#       'windspeedMiles': '5',
#       'windspeedKmph': '8',
#       'winddirDegree': '300',
#       'winddir16Point': 'WNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '28',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '30',
#       'cloudcover': '2',
#       'HeatIndexC': '20',
#       'HeatIndexF': '67',
#       'DewPointC': '-0',
#       'DewPointF': '31',
#       'WindChillC': '19',
#       'WindChillF': '65',
#       'WindGustMiles': '8',
#       'WindGustKmph': '13',
#       'FeelsLikeC': '19',
#       'FeelsLikeF': '65',
#       'uvIndex': '5'},
#      {'time': '1700',
#       'tempC': '16',
#       'tempF': '61',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '326',
#       'winddir16Point': 'NNW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0001_sunny.png'}],
#       'weatherDesc': [{'value': 'Sunny'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '32',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1025',
#       'pressureInches': '30',
#       'cloudcover': '1',
#       'HeatIndexC': '17',
#       'HeatIndexF': '62',
#       'DewPointC': '-1',
#       'DewPointF': '31',
#       'WindChillC': '16',
#       'WindChillF': '60',
#       'WindGustMiles': '12',
#       'WindGustKmph': '20',
#       'FeelsLikeC': '16',
#       'FeelsLikeF': '60',
#       'uvIndex': '5'},
#      {'time': '1800',
#       'tempC': '14',
#       'tempF': '57',
#       'windspeedMiles': '8',
#       'windspeedKmph': '13',
#       'winddirDegree': '352',
#       'winddir16Point': 'N',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '35',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1026',
#       'pressureInches': '30',
#       'cloudcover': '0',
#       'HeatIndexC': '14',
#       'HeatIndexF': '57',
#       'DewPointC': '-1',
#       'DewPointF': '30',
#       'WindChillC': '13',
#       'WindChillF': '55',
#       'WindGustMiles': '17',
#       'WindGustKmph': '27',
#       'FeelsLikeC': '13',
#       'FeelsLikeF': '55',
#       'uvIndex': '1'},
#      {'time': '1900',
#       'tempC': '13',
#       'tempF': '55',
#       'windspeedMiles': '7',
#       'windspeedKmph': '12',
#       'winddirDegree': '245',
#       'winddir16Point': 'WSW',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '33',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1026',
#       'pressureInches': '30',
#       'cloudcover': '1',
#       'HeatIndexC': '13',
#       'HeatIndexF': '55',
#       'DewPointC': '-3',
#       'DewPointF': '27',
#       'WindChillC': '12',
#       'WindChillF': '53',
#       'WindGustMiles': '16',
#       'WindGustKmph': '25',
#       'FeelsLikeC': '12',
#       'FeelsLikeF': '53',
#       'uvIndex': '1'},
#      {'time': '2000',
#       'tempC': '12',
#       'tempF': '54',
#       'windspeedMiles': '7',
#       'windspeedKmph': '11',
#       'winddirDegree': '138',
#       'winddir16Point': 'SE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '32',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1026',
#       'pressureInches': '30',
#       'cloudcover': '2',
#       'HeatIndexC': '12',
#       'HeatIndexF': '54',
#       'DewPointC': '-4',
#       'DewPointF': '24',
#       'WindChillC': '11',
#       'WindChillF': '51',
#       'WindGustMiles': '14',
#       'WindGustKmph': '23',
#       'FeelsLikeC': '11',
#       'FeelsLikeF': '51',
#       'uvIndex': '1'},
#      {'time': '2100',
#       'tempC': '11',
#       'tempF': '52',
#       'windspeedMiles': '6',
#       'windspeedKmph': '10',
#       'winddirDegree': '31',
#       'winddir16Point': 'NNE',
#       'weatherCode': '113',
#       'weatherIconUrl': [{'value': 'http://cdn.worldweatheronline.com/images/wsymbols01_png_64/wsymbol_0008_clear_sky_night.png'}],
#       'weatherDesc': [{'value': 'Clear'}],
#       'precipMM': '0.0',
#       'precipInches': '0.0',
#       'humidity': '30',
#       'visibility': '10',
#       'visibilityMiles': '6',
#       'pressure': '1027',
#       'pressureInches': '30',
#       'cloudcover': '3',
#       'HeatIndexC': '11',
#       'HeatIndexF': '52',
#       'DewPointC': '-6',
#       'DewPointF': '22',
#       'WindChillC': '10',
#       'WindChillF': '49',
#       'WindGustMiles': '13',
#       'WindGustKmph': '20',
#       'FeelsLikeC': '10',
#       'FeelsLikeF': '49',
#       'uvIndex': '1'}]}]}}

# %%
weather_data = pd.DataFrame()
for i in resp['data']["weather"]:
    for j in i["hourly"]:
        temp = pd.DataFrame(j, index=[0])
        temp["date"] = i["date"]
        weather_data = weather_data.append(temp, ignore_index=True)

# %%
resp['data']["weather"][0]["hourly"][0].keys()
# Out:
# dict_keys(['time', 'tempC', 'tempF', 'windspeedMiles', 'windspeedKmph', 'winddirDegree', 'winddir16Point', 'weatherCode', 'weatherIconUrl', 'weatherDesc', 'precipMM', 'precipInches', 'humidity', 'visibility', 'visibilityMiles', 'pressure', 'pressureInches', 'cloudcover', 'HeatIndexC', 'HeatIndexF', 'DewPointC', 'DewPointF', 'WindChillC', 'WindChillF', 'WindGustMiles', 'WindGustKmph', 'FeelsLikeC', 'FeelsLikeF', 'uvIndex'])

# %%
weather_data = pd.DataFrame()
for i in resp['data']["weather"]:
    for j in i["hourly"]:
        temp = pd.DataFrame(j, index=[0])
        temp["date"] = i["date"]
        weather_data = weather_data.append(temp, ignore_index=True)
data_sorted = weather_data.drop(columns = ['tempF', 'windspeedMiles', 'winddir16Point', 'weatherCode', 'weatherIconUrl', 'weatherDesc', 'precipInches','visibilityMiles','pressureInches', 'HeatIndexC', 'HeatIndexF','DewPointF', 'WindChillC', 'WindChillF', 'WindGustMiles', 'FeelsLikeC', 'FeelsLikeF', 'uvIndex'])    #data_sorted = data_sorted.drop(data_sorted[data_sorted["sample_duration"] == "24 HOUR"].index)

# %%
data_sorted
# Out:
#      time tempC windspeedKmph winddirDegree precipMM humidity visibility  \
# 0       0     7            14            10      0.0       35         10
# 1     100     7            14            17      0.0       34         10
# 2     200     7            14            25      0.0       34         10
# 3     300     6            14            32      0.0       34         10
# 4     400     6            15            24      0.0       34         10
# ..    ...   ...           ...           ...      ...      ...        ...
# 833  1700    16            10           326      0.0       32         10
# 834  1800    14            13           352      0.0       35         10
# 835  1900    13            12           245      0.0       33         10
# 836  2000    12            11           138      0.0       32         10
# 837  2100    11            10            31      0.0       30         10
#
#     pressure cloudcover DewPointC WindGustKmph        date
# 0       1020          0        -8           30  2016-01-01
# 1       1020          1        -8           30  2016-01-01
# 2       1020          1        -8           30  2016-01-01
# 3       1020          2        -8           30  2016-01-01
# 4       1020          2        -9           30  2016-01-01
# ..       ...        ...       ...          ...         ...
# 833     1025          1        -1           20  2016-02-04
# 834     1026          0        -1           27  2016-02-04
# 835     1026          1        -3           25  2016-02-04
# 836     1026          2        -4           23  2016-02-04
# 837     1027          3        -6           20  2016-02-04
#
# [838 rows x 12 columns]

# %%
data = pd.DataFrame(columns = resp["Data"][0].keys())
